# %%
nome = 'Ailton Teixeira de Souza Filho'
peso = 52
print(nome,'tem',peso,'kg!')
print('A variável "nome" está no endereço',hex(id(nome)))
print('A variável "peso" está no endereço',hex(id(peso)))
# Out:
# Ailton Teixeira de Souza Filho tem 52 kg!
# A variável "nome" está no endereço 0x7f7eb39fd0d0
# A variável "peso" está no endereço 0xabc760

# %%
matricula = 'N8398A2'
curso = 'Ciencia da Computacao'
idade = 17
print('Minha matrícula é',matricula,'eu curso',curso,'e tenho',idade,'anos.')
print('A variável "matricula" está no endereço',hex(id(matricula)))
print('A variável "curso" está no endereço',hex(id(curso)))
print('A variável "idade" está no endereço',hex(id(idade)))
# Out:
# Minha matrícula é N8398A2  eu curso Ciencia da Computacao e tenho 17 anos.
# A variável "matricula" está no endereço 0x7f7eb39d97f0
# A variável "curso" está no endereço 0x7f7eb39dda80
# A variável "idade" está no endereço 0xabc300

# %%
a = 7
b = 5
print('Soma:',a+b) 
print('Subtracao:',a-b)
print('Multiplicacao:',a*b) 
print('Divisao:',a/b) 
print('Divisao Inteira:',a//b) 
print('Resto ou Modulo:',a%b) 
print('Exponeciacao:',a**b)
# Out:
# Soma: 12
# Subtracao: 2
# Multiplicacao: 35
# Divisao: 1.4
# Divisao Inteira: 1
# Resto ou Modulo: 2
# Exponeciacao: 16807

# %%
a = 20
b = 10
print('Soma:',a+b) 
print('Subtracao:',a-b)
print('Multiplicacao:',a*b) 
print('Divisao:',a/b) 
print('Divisao Inteira:',a//b) 
print('Resto ou Modulo:',a%b) 
print('Exponeciacao:',a**b)

# %%
a = 8
b = 3
print('Soma:',a+b) 
print('Subtracao:',a-b)
print('Multiplicacao:',a*b) 
print('Divisao:',a/b) 
print('Divisao Inteira:',a//b) 
print('Resto ou Modulo:',a%b) 
print('Exponeciacao:',a**b)

# %%
a = 1024
b = 512
print('Soma:',a+b) 
print('Subtracao:',a-b)
print('Multiplicacao:',a*b) 
print('Divisao:',a/b) 
print('Divisao Inteira:',a//b) 
print('Resto ou Modulo:',a%b) 
print('Exponeciacao:',a**b)

# %%
a = 99
b = 53
print('Soma:',a+b) 
print('Subtracao:',a-b)
print('Multiplicacao:',a*b) 
print('Divisao:',a/b) 
print('Divisao Inteira:',a//b) 
print('Resto ou Modulo:',a%b) 
print('Exponeciacao:',a**b)

# %%
import math
print('Arredondamento para cima:',math.ceil(5.8))
print('Arredondamento para baixo:',math.floor(5.8))
print('Valor absoluto:',math.fabs(5.8))
# Out:
# Arredondamento para cima: 6
# Arredondamento para baixo: 5
# Valor absoluto: 5.8

# %%
import math
print('Arredondamento para cima:',math.ceil(-9.7))
print('Arredondamento para baixo:',math.floor(-9.7))
print('Valor absoluto:',math.fabs(-9.7))
# Out:
# Arredondamento para cima: -9
# Arredondamento para baixo: -10
# Valor absoluto: 9.7

# %%
import math
print('Arredondamento para cima:',math.ceil(-10.2))
print('Arredondamento para baixo:',math.floor(-10.2))
print('Valor absoluto:',math.fabs(-10.2))
# Out:
# Arredondamento para cima: -10
# Arredondamento para baixo: -11
# Valor absoluto: 10.2

# %%
import math
print('Arredondamento para cima:',math.ceil(33.6))
print('Arredondamento para baixo:',math.floor(33.6))
print('Valor absoluto:',math.fabs(33.6))
# Out:
# Arredondamento para cima: 34
# Arredondamento para baixo: 33
# Valor absoluto: 33.6

# %%
import math
print('Arredondamento para cima:',math.ceil(-25.5))
print('Arredondamento para baixo:',math.floor(-25.5))
print('Valor absoluto:',math.fabs(-25.5))
# Out:
# Arredondamento para cima: -25
# Arredondamento para baixo: -26
# Valor absoluto: 25.5

# %%
import math
print('Fatorial:', math.factorial(5))
# Out:
# Fatorial: 120

# %%
import math
print('Fatorial:', math.factorial(9))
# Out:
# Fatorial: 362880

# %%
import math
print('Fatorial:', math.factorial(12))
# Out:
# Fatorial: 479001600

# %%
import math
print('Fatorial:', math.factorial(22))
# Out:
# Fatorial: 1124000727777607680000

# %%
import math
print('Maior divisor comum:',math.gcd(5,35))
# Out:
# Maior divisor comum: 5

# %%
import math
print('Maior divisor comum:',math.gcd(9,12))
# Out:
# Maior divisor comum: 3

# %%
import math
print('Maior divisor comum:',math.gcd(1024,512))
# Out:
# Maior divisor comum: 512

# %%
import math
print('Maior divisor comum:',math.gcd(22,44))
# Out:
# Maior divisor comum: 22

# %%
import math
print('Maior divisor comum:',math.gcd(36,90))
# Out:
# Maior divisor comum: 18

# %%
import math
print('Raiz quadrada:',math.sqrt(39))
# Out:
# Raiz quadrada: 6.244997998398398

# %%
import math
print('Raiz quadrada:',math.sqrt(100))
# Out:
# Raiz quadrada: 10.0

# %%
import math
print('Raiz quadrada:',math.sqrt(45))
# Out:
# Raiz quadrada: 6.708203932499369

# %%
import math
print('Raiz quadrada:',math.sqrt(18))
# Out:
# Raiz quadrada: 4.242640687119285

# %%
import math
print('Raiz quadrada:',math.sqrt(6))
# Out:
# Raiz quadrada: 2.449489742783178

# %%
import math
print('Seno:',round(math.sin(45)))
print('Coseno:',round(math.cos(45)))
print('Tangente:',round(math.tan(45)))
print('Seno em graus:',round(math.sin(math.radians(45))))
print('Coseno em graus:',round(math.cos(math.radians(45)))) 
print('Tangente em graus:',round(math.tan(math.radians(45))))
# Out:
# Seno: 1
# Coseno: 1
# Tangente: 2
# Seno em graus: 1
# Coseno em graus: 1
# Tangente em graus: 1

# %%
import math
print('Seno:',round(math.sin(60)))
print('Coseno:',round(math.cos(60)))
print('Tangente:',round(math.tan(60)))
print('Seno em graus:',round(math.sin(math.radians(60))))
print('Coseno em graus:',round(math.cos(math.radians(60)))) 
print('Tangente em graus:',round(math.tan(math.radians(60))))
# Out:
# Seno: 0
# Coseno: -1
# Tangente: 0
# Seno em graus: 1
# Coseno em graus: 1
# Tangente em graus: 2

# %%
import math
print('Seno:',round(math.sin(90)))
print('Coseno:',round(math.cos(90)))
print('Tangente:',round(math.tan(90)))
print('Seno em graus:',round(math.sin(math.radians(90))))
print('Coseno em graus:',round(math.cos(math.radians(90)))) 
print('Tangente em graus:',round(math.tan(math.radians(90))))
# Out:
# Seno: 1
# Coseno: 0
# Tangente: -2
# Seno em graus: 1
# Coseno em graus: 0
# Tangente em graus: 16331239353195370

# %%
import math
print('Seno:',round(math.sin(180)))
print('Coseno:',round(math.cos(180)))
print('Tangente:',round(math.tan(180)))
print('Seno em graus:',round(math.sin(math.radians(180))))
print('Coseno em graus:',round(math.cos(math.radians(180)))) 
print('Tangente em graus:',round(math.tan(math.radians(180))))
# Out:
# Seno: -1
# Coseno: -1
# Tangente: 1
# Seno em graus: 0
# Coseno em graus: -1
# Tangente em graus: 0

# %%
import math
print('Seno:',round(math.sin(270)))
print('Coseno:',round(math.cos(270)))
print('Tangente:',round(math.tan(270)))
print('Seno em graus:',round(math.sin(math.radians(270))))
print('Coseno em graus:',round(math.cos(math.radians(270)))) 
print('Tangente em graus:',round(math.tan(math.radians(270))))
# Out:
# Seno: 0
# Coseno: 1
# Tangente: 0
# Seno em graus: -1
# Coseno em graus: 0
# Tangente em graus: 5443746451065123

# %%
import math
print('Seno:',round(math.sin(360)))
print('Coseno:',round(math.cos(360)))
print('Tangente:',round(math.tan(360)))
print('Seno em graus:',round(math.sin(math.radians(360))))
print('Coseno em graus:',round(math.cos(math.radians(360)))) 
print('Tangente em graus:',round(math.tan(math.radians(360))))
# Out:
# Seno: 1
# Coseno: 0
# Tangente: -3
# Seno em graus: 0
# Coseno em graus: 1
# Tangente em graus: 0

# %%
#Exercício A
tuplacarro = ('Toyota', ['Corolla','Etios','Hilux'])
tuplacarro
# Out:
# ('Toyota', ['Corolla', 'Etios', 'Hilux'])

# %%
#Exercício B
tuplacarro = ('Toyota',['Corolla','Etios','Hilux'])
tuplacarro[1][0] = 'SW4'
tuplacarro
# Out:
# ('Toyota', ['SW4', 'Etios', 'Hilux'])

# %%
#Exercício C - 1
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
X.union(Y)
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'g'}

# %%
#Exercício C - 2
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
X.intersection(Y)
# Out:
# {'d', 'e'}

# %%
#Exercício C - 3
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
X.intersection_update(Y)
print(X)
print(Y)
# Out:
# {'e', 'd'}
# {'e', 'f', 'g', 'd'}

# %%
#Exercício C - 4
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
print(X.difference(Y))
print(Y.difference(X))
# Out:
# {'b', 'a', 'c'}
# {'f', 'g'}

# %%
#Exercício C - 5
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
print(X.symmetric_difference(Y))
# Out:
# {'b', 'a', 'f', 'g', 'c'}

# %%
#Exercício C - 6
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
print('f' in X)
print('e' in X)
# Out:
# False
# True

# %%
#Exercício C - 7
X = {'a','b','c','d','e'}
Z = {'a','b'}
print(Z.issubset(X))
# Out:
# True

# %%
#Exercício C - 7
X = {'a','b','c','d','e'}
Z = {'a','b'}
print(Z.issuperset(X))
# Out:
# False

# %%
#Exercício C - 7
X = {'a','b','c','d','e'}
Y = {'d','e','f','g'}
print(X.isdisjoint(Y))
# Out:
# False

# %%
#Exercício D
cadastro = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro)
print(cadastro)
# Out:
# {'Nelson': '127.124.642-87', 'Ryan': '325.651.414-65', 'Ailton': '031.923.231-08', 'Gabriel': '205.481.423-61', 'Jorge': '872.612.795-00', 'Fhilipe': '147.196.541-95'}

# %%
#Exercício E
cadastro = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro)
print('O CPF da terceira pessoa é:',cadastro['Ailton'])
# Out:
# O CPF da terceira pessoa é: 031.923.231-08

# %%
#Exercício F
cadastro = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro)
print(cadastro.get('Afonso','Nome inválido'))
print(cadastro.get('Ailton','Nome inválido'))
# Out:
# Nome inválido
# 031.923.231-08

# %%
#Exercício G
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro_lista)
print('127.124.642-87' in cadastro['Nelson'])
print('790.651.517-51' in cadastro['Nelson'])
# Out:
# True
# False

# %%
#Exercício H
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro_lista)
cadastro['Ryan'] = '863.214.640-40'
print(cadastro)
# Out:
# {'Nelson': '127.124.642-87', 'Ryan': '863.214.640-40', 'Ailton': '031.923.231-08', 'Gabriel': '205.481.423-61', 'Jorge': '872.612.795-00', 'Fhilipe': '147.196.541-95'}

# %%
#Exercício I
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro_lista)
del cadastro['Jorge']
print(cadastro)
# Out:
# {'Nelson': '127.124.642-87', 'Ryan': '325.651.414-65', 'Ailton': '031.923.231-08', 'Gabriel': '205.481.423-61', 'Fhilipe': '147.196.541-95'}

# %%
#Exercício J
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro_lista)
print(cadastro.pop('Nelson','Nome inválido'))
print(cadastro.pop('Luiz','Nome inválido'))
print(cadastro)
# Out:
# 127.124.642-87
# Nome inválido
# {'Ryan': '325.651.414-65', 'Ailton': '031.923.231-08', 'Gabriel': '205.481.423-61', 'Jorge': '872.612.795-00', 'Fhilipe': '147.196.541-95'}

# %%
#Exercício K
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro_lista2 = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Luiz', '315.751.454-25'), ('Bruno', '011.223.241-09')]
cadastro = dict(cadastro_lista)
cadastro2 = dict(cadastro_lista2)
cadastro.update(cadastro2)
print(cadastro)
# Out:
# {'Nelson': '127.124.642-87', 'Ryan': '325.651.414-65', 'Ailton': '031.923.231-08', 'Gabriel': '205.481.423-61', 'Jorge': '872.612.795-00', 'Fhilipe': '147.196.541-95', 'Luiz': '315.751.454-25', 'Bruno': '011.223.241-09'}

# %%
#Exercício L
cadastro_lista = [('Nelson', '127.124.642-87'), ('Ryan', '325.651.414-65'), ('Ailton', '031.923.231-08'), 
            ('Gabriel', '205.481.423-61'), ('Jorge','872.612.795-00'), ('Fhilipe', '147.196.541-95')]
cadastro = dict(cadastro_lista)
cadastro_lista_novo = {cpf: '*' + cadastro[cpf] for cpf in cadastro}
print(cadastro_lista_novo)
# Out:
# {'Nelson': '*127.124.642-87', 'Ryan': '*325.651.414-65', 'Ailton': '*031.923.231-08', 'Gabriel': '*205.481.423-61', 'Jorge': '*872.612.795-00', 'Fhilipe': '*147.196.541-95'}
